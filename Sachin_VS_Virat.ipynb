# %% [markdown]
# <a href="https://colab.research.google.com/github/mayankpatil07/SACHIN-VS-VIRAT/blob/main/Sachin_VS_Virat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings('ignore')

#to display all rows and columns
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)
pd.set_option('display.expand_frame_repr',False)
pd.set_option('max_colwidth',None)

# %%
df=pd.read_csv('ODI_data.csv')

# %%
df.head()
# Out:
#   Innings Player Innings Runs Scored Innings Runs Scored Num Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes Innings Batting Strike Rate Innings Number Opposition         Ground Innings Date      Country  50's  100's Innings Runs Scored Buckets Innings Overs Bowled  Innings Bowled Flag Innings Maidens Bowled Innings Runs Conceded Innings Wickets Taken  4 Wickets  5 Wickets  10 Wickets Innings Wickets Taken Buckets Innings Economy Rate
# ...

# %%
df.columns
# Out:
# Index(['Innings Player', 'Innings Runs Scored', 'Innings Runs Scored Num',
#        'Innings Minutes Batted', 'Innings Batted Flag', 'Innings Not Out Flag',
#        'Innings Balls Faced', 'Innings Boundary Fours',
#        'Innings Boundary Sixes', 'Innings Batting Strike Rate',
#        'Innings Number', 'Opposition', 'Ground', 'Innings Date', 'Country',
#        '50's', '100's', 'Innings Runs Scored Buckets', 'Innings Overs Bowled',
#        'Innings Bowled Flag', 'Innings Maidens Bowled',
#        'Innings Runs Conceded', 'Innings Wickets Taken', '4 Wickets',
#        '5 Wickets', '10 Wickets', 'Innings Wickets Taken Buckets',
#        'Innings Economy Rate'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 28

# %%
df.head(2)
# Out:
#   Innings Player Innings Runs Scored Innings Runs Scored Num Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes Innings Batting Strike Rate Innings Number Opposition         Ground Innings Date      Country  50's  100's Innings Runs Scored Buckets Innings Overs Bowled  Innings Bowled Flag Innings Maidens Bowled Innings Runs Conceded Innings Wickets Taken  4 Wickets  5 Wickets  10 Wickets Innings Wickets Taken Buckets Innings Economy Rate
# ...

# %%
#runs per innings
#strike rate
#100's
#50's
#team contribution

# %%
df['Innings Runs Scored Num'].unique()
# Out:
# array(['65', '42', '18', '17', '13', '11', '5', '0', '120', '71', '20',
#        '16', '3', '2', '1', '-', nan, '40', '6', '4', '87', '54', '46',
#        '30', '12', '69', '39', '14', '10', '9', '8', '7', '82', '52',
#        '41', '15', '98', '43', '19', '111', '48', '36', '25', '67', '60',
#        '84', '59', '55', '47', '85', '49', '45', '34', '29', '22', '74',
#        '28', '77', '50', '32', '23', '35', '122', '100', '95', '103',
#        '113', '53', '96', '27', '64', '58', '33', '31', '73', '56', '86',
#        '62', '106', '24', '57', '104', '26', '66', '51', '118', '105',
#        '101', '21', '79', '44', '102', '88', '80', '72', '97', '68', '89',
#        '38', '83', '63', '148', '166', '90', '76', '37', '70', '124',
#        '94', '140', '153', '107', '117', '121', '92', '78', '75', '114',
#        '115', '130', '128', '151', '110', '138', '135', '109', '61',
#        '179', '170', '112', '116', '91', '143', '93', '123', '145', '81',
# ...

# %%
df = df[df['Innings Runs Scored Num']!= '-'] #remove the hypens

# %%
df['Innings Runs Scored Num'].unique()
# Out:
# array(['65', '42', '18', '17', '13', '11', '5', '0', '120', '71', '20',
#        '16', '3', '2', '1', nan, '40', '6', '4', '87', '54', '46', '30',
#        '12', '69', '39', '14', '10', '9', '8', '7', '82', '52', '41',
#        '15', '98', '43', '19', '111', '48', '36', '25', '67', '60', '84',
#        '59', '55', '47', '85', '49', '45', '34', '29', '22', '74', '28',
#        '77', '50', '32', '23', '35', '122', '100', '95', '103', '113',
#        '53', '96', '27', '64', '58', '33', '31', '73', '56', '86', '62',
#        '106', '24', '57', '104', '26', '66', '51', '118', '105', '101',
#        '21', '79', '44', '102', '88', '80', '72', '97', '68', '89', '38',
#        '83', '63', '148', '166', '90', '76', '37', '70', '124', '94',
#        '140', '153', '107', '117', '121', '92', '78', '75', '114', '115',
#        '130', '128', '151', '110', '138', '135', '109', '61', '179',
#        '170', '112', '116', '91', '143', '93', '123', '145', '81', '150',
# ...

# %%
df = df.dropna(subset=['Innings Runs Scored Num']) #to remove the nan

# %%
df['Innings Runs Scored Num'].unique()
# Out:
# array(['65', '42', '18', '17', '13', '11', '5', '0', '120', '71', '20',
#        '16', '3', '2', '1', '40', '6', '4', '87', '54', '46', '30', '12',
#        '69', '39', '14', '10', '9', '8', '7', '82', '52', '41', '15',
#        '98', '43', '19', '111', '48', '36', '25', '67', '60', '84', '59',
#        '55', '47', '85', '49', '45', '34', '29', '22', '74', '28', '77',
#        '50', '32', '23', '35', '122', '100', '95', '103', '113', '53',
#        '96', '27', '64', '58', '33', '31', '73', '56', '86', '62', '106',
#        '24', '57', '104', '26', '66', '51', '118', '105', '101', '21',
#        '79', '44', '102', '88', '80', '72', '97', '68', '89', '38', '83',
#        '63', '148', '166', '90', '76', '37', '70', '124', '94', '140',
#        '153', '107', '117', '121', '92', '78', '75', '114', '115', '130',
#        '128', '151', '110', '138', '135', '109', '61', '179', '170',
#        '112', '116', '91', '143', '93', '123', '145', '81', '150', '162',
# ...

# %%
df.head(1)
# Out:
#   Innings Player Innings Runs Scored Innings Runs Scored Num Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes Innings Batting Strike Rate Innings Number Opposition         Ground Innings Date      Country  50's  100's Innings Runs Scored Buckets Innings Overs Bowled  Innings Bowled Flag Innings Maidens Bowled Innings Runs Conceded Innings Wickets Taken  4 Wickets  5 Wickets  10 Wickets Innings Wickets Taken Buckets Innings Economy Rate
# ...

# %%
#convert to datetime
df['Innings Date'] = pd.to_datetime(df['Innings Date'], format='%d-%m-%Y')

# %%
df['year'] = df['Innings Date'].dt.year

# %%
df.head(1)
# Out:
#   Innings Player Innings Runs Scored Innings Runs Scored Num Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes Innings Batting Strike Rate Innings Number Opposition         Ground Innings Date      Country  50's  100's Innings Runs Scored Buckets Innings Overs Bowled  Innings Bowled Flag Innings Maidens Bowled Innings Runs Conceded Innings Wickets Taken  4 Wickets  5 Wickets  10 Wickets Innings Wickets Taken Buckets Innings Economy Rate  year
# ...

# %%
df['Innings Runs Scored Num']=df['Innings Runs Scored Num'].astype(int)
df['Innings Balls Faced']=df['Innings Balls Faced'].astype('int')

# %%
df['Innings Not Out Flag']=df['Innings Not Out Flag'].astype('int')

# %%
# sachin 1st century 1994 - 2004
# virat 1st century 2009 - 2019

# %%
sachin_df = df[(df['year'] >= 1994) & (df['year'] <= 2004)]

# %%
kohli_df = df[(df['year'] >= 2009) & (df['year'] <= 2019)]

# %%
sachin_df.head(1)
# Out:
#       Innings Player Innings Runs Scored  Innings Runs Scored Num Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes Innings Batting Strike Rate Innings Number    Opposition Ground Innings Date Country  50's  100's Innings Runs Scored Buckets Innings Overs Bowled  Innings Bowled Flag Innings Maidens Bowled Innings Runs Conceded Innings Wickets Taken  4 Wickets  5 Wickets  10 Wickets Innings Wickets Taken Buckets Innings Economy Rate  year
# ...

# %%
kohli_df.head(1)
# Out:
#   Innings Player Innings Runs Scored  Innings Runs Scored Num Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes Innings Batting Strike Rate Innings Number Opposition         Ground Innings Date      Country  50's  100's Innings Runs Scored Buckets Innings Overs Bowled  Innings Bowled Flag Innings Maidens Bowled Innings Runs Conceded Innings Wickets Taken  4 Wickets  5 Wickets  10 Wickets Innings Wickets Taken Buckets Innings Economy Rate  year
# ...

# %%
#runs per innings - total runs/total innings
#strike rate - (total runs/total balls)*100
#100's - sum of all 100
#50's - sum of 50's
#team contribution - players runs/team runs (ex: virat scored 50/ team india scored 150) -> 50/150 : 33% runs scored by virat

# %%
df.dtypes
# Out:
# Innings Player                           object
# Innings Runs Scored                      object
# Innings Runs Scored Num                   int64
# Innings Minutes Batted                   object
# Innings Batted Flag                     float64
# Innings Not Out Flag                      int64
# Innings Balls Faced                       int64
# Innings Boundary Fours                   object
# Innings Boundary Sixes                   object
# Innings Batting Strike Rate              object
# Innings Number                           object
# Opposition                               object
# Ground                                   object
# Innings Date                     datetime64[ns]
# Country                                  object
# 50's                                    float64
# 100's                                   float64
# Innings Runs Scored Buckets              object
# Innings Overs Bowled                     object
# Innings Bowled Flag                     float64
# ...

# %%
#what is the total runs scored by sachin in this time frame

# %%
sachin_df.head(20)
# Out:
#           Innings Player Innings Runs Scored  Innings Runs Scored Num Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes Innings Batting Strike Rate Innings Number    Opposition    Ground Innings Date      Country  50's  100's Innings Runs Scored Buckets Innings Overs Bowled  Innings Bowled Flag Innings Maidens Bowled Innings Runs Conceded Innings Wickets Taken  4 Wickets  5 Wickets  10 Wickets Innings Wickets Taken Buckets Innings Economy Rate  year
# ...

# %%
sdf=sachin_df[sachin_df['Innings Player'] == 'SR Tendulkar']

# %%
sdf.head()
# Out:
#       Innings Player Innings Runs Scored  Innings Runs Scored Num Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes Innings Batting Strike Rate Innings Number    Opposition         Ground Innings Date Country  50's  100's Innings Runs Scored Buckets Innings Overs Bowled  Innings Bowled Flag Innings Maidens Bowled Innings Runs Conceded Innings Wickets Taken  4 Wickets  5 Wickets  10 Wickets Innings Wickets Taken Buckets Innings Economy Rate  year
# ...

# %%
sum(sdf['Innings Runs Scored Num'])
# Out:
# 11818

# %%
kdf = kohli_df[kohli_df['Innings Player'] == 'V Kohli']

# %%
kdf.head()
# Out:
#     Innings Player Innings Runs Scored  Innings Runs Scored Num Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes Innings Batting Strike Rate Innings Number     Opposition         Ground Innings Date Country  50's  100's Innings Runs Scored Buckets Innings Overs Bowled  Innings Bowled Flag Innings Maidens Bowled Innings Runs Conceded Innings Wickets Taken  4 Wickets  5 Wickets  10 Wickets Innings Wickets Taken Buckets Innings Economy Rate  year
# ...

# %%
sum(kdf['Innings Runs Scored Num'])
# Out:
# 11247

# %%
#runs per innings for sachin and virat

# %%
len(sdf), len(kdf)
# Out:
# (271, 224)

# %%
sum(sdf['Innings Runs Scored Num'])/len(sdf) , sum(kdf['Innings Runs Scored Num'])/len(kdf)
# Out:
# (43.608856088560884, 50.20982142857143)

# %%
#SR of both the batsman

# %%
sum(sdf['Innings Balls Faced'])
# Out:
# 13397

# %%
sum(kdf['Innings Balls Faced'])
# Out:
# 12021

# %%
sum(sdf['Innings Runs Scored Num'])/sum(sdf['Innings Balls Faced'])*100 , sum(kdf['Innings Runs Scored Num'])/sum(kdf['Innings Balls Faced'])*100
# Out:
# (88.21377920429947, 93.56126778138258)

# %%
#100's

# %%
sum(sdf["100's"]), sum(kdf["100's"])
# Out:
# (37.0, 42.0)

# %%
#50's

# %%
sum(sdf["50's"]), sum(kdf["50's"])
# Out:
# (57.0, 53.0)

# %%
#team contribution - runs scored by each player, runs by team
sum(sdf['Innings Runs Scored Num']), sum(kdf['Innings Runs Scored Num'])
# Out:
# (11818, 11247)

# %%
#1994-2004 total players runs scored
sachin_df[sachin_df.Country == 'India']['Innings Runs Scored Num'].sum()
# Out:
# 69715

# %%
#2009-2019 total players runs scored
kohli_df[kohli_df.Country == 'India']['Innings Runs Scored Num'].sum()
# Out:
# 63867

# %%
#total team contribution % of sachin and kohli
sum(sdf['Innings Runs Scored Num'])/sachin_df[sachin_df.Country == 'India']['Innings Runs Scored Num'].sum() *100, sum(kdf['Innings Runs Scored Num'])/kohli_df[kohli_df.Country == 'India']['Innings Runs Scored Num'].sum() * 100
# Out:
# (16.951875493078962, 17.610033350556627)

# %%
##visualizations

# %%
sachin_df.groupby('Innings Player')['Innings Runs Scored Num'].sum().sort_values(ascending=False).head(10)
# Out:
# Innings Player
# SR Tendulkar      11818
# SC Ganguly         9911
# ST Jayasuriya      9297
# Inzamam-ul-Haq     8561
# R Dravid           7751
# RT Ponting         7422
# Saeed Anwar        7320
# JH Kallis          7267
# MS Atapattu        7253
# MG Bevan           6912
# Name: Innings Runs Scored Num, dtype: int64

# %%
sachin_df.groupby('Innings Player')['Innings Runs Scored Num'].sum().sort_values(ascending=False).head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='Innings Player'>

# %%
kohli_df.groupby('Innings Player')['Innings Runs Scored Num'].sum().sort_values(ascending=False).head(10)
# Out:
# Innings Player
# V Kohli           11247
# RG Sharma          8083
# HM Amla            7745
# TM Dilshan         7296
# KC Sangakkara      7275
# AB de Villiers     7247
# LRPL Taylor        7059
# MS Dhoni           6838
# EJG Morgan         6748
# MJ Guptill         6626
# Name: Innings Runs Scored Num, dtype: int64

# %%
kohli_df.groupby('Innings Player')['Innings Runs Scored Num'].sum().sort_values(ascending=False).head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='Innings Player'>

# %%
sdf.head(1)
# Out:
#       Innings Player Innings Runs Scored  Innings Runs Scored Num Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes Innings Batting Strike Rate Innings Number    Opposition Ground Innings Date Country  50's  100's Innings Runs Scored Buckets Innings Overs Bowled  Innings Bowled Flag Innings Maidens Bowled Innings Runs Conceded Innings Wickets Taken  4 Wickets  5 Wickets  10 Wickets Innings Wickets Taken Buckets Innings Economy Rate  year
# ...

# %%
sdf.groupby(['year'])['Innings Runs Scored Num'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='year'>

# %%
kdf.groupby(['year'])['Innings Runs Scored Num'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='year'>

# %%
#NORMALIZATION

# %%
#rpi -sachin, virat
sum(sdf['Innings Runs Scored Num'])/len(sdf), sum(kdf['Innings Runs Scored Num'])/len(kdf)
# Out:
# (43.608856088560884, 50.20982142857143)

# %%
#sachin_df=player runs with sachin
#player runs excluding sachin -> not_sachin = sachin_df[sachin_df.player_name!=sachin]

# %%
sum(sachin_df['Innings Runs Scored Num'])/len(sachin_df)
# Out:
# 22.69352006124195

# %%
non_sachin_df = sachin_df[sachin_df['Innings Player'] != 'SR Tendulkar']

# %%
#SACHIN
(sum(sdf['Innings Runs Scored Num'])/len(sdf))/(sum(non_sachin_df['Innings Runs Scored Num'])/len(non_sachin_df))
# Out:
# 1.9437755485945407

# %%
non_kohli_df = kohli_df[kohli_df['Innings Player'] != 'V Kohli']

# %%
#KOHLI
(sum(kdf['Innings Runs Scored Num'])/len(kdf))/(sum(non_kohli_df['Innings Runs Scored Num'])/len(non_kohli_df))
# Out:
# 2.029683688052565

# %%
#strike rate

# %%
sum(non_sachin_df['Innings Runs Scored Num'])/sum(non_sachin_df['Innings Balls Faced'])*100
# Out:
# 72.33808936558636

# %%
#SACHIN
(sum(sdf['Innings Runs Scored Num'])/sum(sdf['Innings Balls Faced'])*100)/(sum(non_sachin_df['Innings Runs Scored Num'])/sum(non_sachin_df['Innings Balls Faced'])*100)
# Out:
# 1.2194651528391862

# %%
#KOHLI
(sum(kdf['Innings Runs Scored Num'])/sum(kdf['Innings Balls Faced'])*100)/(sum(non_kohli_df['Innings Runs Scored Num'])/sum(non_kohli_df['Innings Balls Faced'])*100)
# Out:
# 1.1214688399967323

# %%
#MATCHES FOR 100's

# %%
len(sdf)/sum(sdf["100's"])
# Out:
# 7.324324324324325

# %%
len(non_sachin_df)/sum(non_sachin_df["100's"])
# Out:
# 47.377969762419006

# %%
#SACHIN
(len(sdf)/sum(sdf["100's"]))/(len(non_sachin_df)/sum(non_sachin_df["100's"]))
# Out:
# 0.15459346107595562

# %%
#KOHLI
(len(kdf)/sum(kdf["100's"]))/(len(non_kohli_df)/sum(non_kohli_df["100's"]))
# Out:
# 0.18195157740278795

# %%
#MATCHES FOR 50's

# %%
#sachin
(len(sdf)/sum(sdf["50's"]))/(len(non_sachin_df)/sum(non_sachin_df["50's"]))
# Out:
# 0.5702402203539483

# %%
#kohli
(len(kdf)/sum(kdf["50's"]))/(len(non_kohli_df)/sum(non_kohli_df["50's"]))
# Out:
# 0.5507828181453231

# %%
#total team contribution % of sachin and kohli
sum(sdf['Innings Runs Scored Num'])/sachin_df[sachin_df.Country == 'India']['Innings Runs Scored Num'].sum() *100, sum(kdf['Innings Runs Scored Num'])/kohli_df[kohli_df.Country == 'India']['Innings Runs Scored Num'].sum() * 100
# Out:
# (16.951875493078962, 17.610033350556627)

# %% [markdown]
# # **FINAL COMPARISONS BETWEEN SACHIN AND KOHLI**

# %% [markdown]
# ![image.png](data:image/png;base64,...)
